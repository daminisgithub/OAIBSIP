# %%
import datetime

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
dataset = pd.read_csv("CarPrice_Assignment.csv")
dataset.head(5)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset.iloc[:, :-1],
                                                    dataset.iloc[:, -1],
                                                    test_size = 0.3,
                                                    random_state = 42)

# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Load the dataset
dataset = pd.read_csv("CarPrice_Assignment.csv")
dataset.head(5)
# Identify categorical columns
categorical_cols = ['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']

# Identify numeric columns
numeric_cols = [col for col in dataset.columns if col not in categorical_cols and col != 'price']

# Define column transformers
numeric_transformer = StandardScaler()
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# Define the model
model = Pipeline(steps=[('preprocessor', preprocessor),
                       ('regressor', RandomForestRegressor(random_state=42))])

# Split the dataset into features (X) and target (y)
X = dataset.drop(columns=['price'])
y = dataset['price']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Fit the model
model.fit(X_train, y_train)

# Predict car prices on the test data
y_pred = model.predict(X_test)

# Display the predicted prices alongside the actual prices
predicted_prices = pd.DataFrame({'Actual Price': y_test, 'Predicted Price': y_pred})
print(predicted_prices)

# # Evaluate the model's performance using R-squared
# r2 = r2_score(y_test, y_pred)
# print(f'R-squared: {r2:.2f}')
# Out:
#      Actual Price  Predicted Price
# 15      30760.000        35100.425
# 9       17859.167        19411.100
# 100      9549.000         9041.600
# 132     11850.000        13394.940
# 68      28248.000        28616.975
# ..            ...              ...
# 56      11845.000        13592.960
# 128     37028.000        32757.015
# 76       5389.000         5964.050
# 144      9233.000        11483.390
# 104     17199.000        18390.260
#
# [62 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# Get the top 5 car examples by mean price
top_5_cars = car_price_mean.head(5)

# Create a bar graph
plt.figure(figsize=(10, 6))
plt.bar(top_5_cars['CarName'], top_5_cars['price'], color='skyblue', label='Mean Price', width=0.6)
plt.xlabel('Car Name')
plt.ylabel('Mean Price')
plt.title('Top 5 Car Prices by Car Name')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.tight_layout()

# Add predicted prices as text above the bars for cars in the test dataset
for index, row in top_5_cars.iterrows():
    car_name = row['CarName']
    mean_price = row['price']
    # Check if the car exists in the test dataset
    if car_name in X_test['CarName'].values:
        # Find the corresponding car in the test set
        test_car = X_test[X_test['CarName'] == car_name].iloc[0:1]  # Get the DataFrame slice
        # Predict the price for this car
        predicted_price = model.predict(test_car)[0]  # Use test_car as a DataFrame
        # Add the predicted price as text above the bar
        plt.text(car_name, mean_price + 500, f'Predicted: ${predicted_price:.2f}', ha='center', fontsize=9)
    else:
        # If the car is not found in the test dataset, continue without displaying it
        continue

# Show the graph
plt.legend()
plt.show()
